# %%
import pandas as pd
import seaborn as sns
from sklearn import linear_model

# %%
df=pd.read_csv(r"D:\Data centr\Exel_data\own data\insur.csv")

# %%
df
# Out:
#    s.no  age  premium
# 0     0   25    18000
# 1     1   30    32000
# 2     2   35    40000
# 3     3   40    47000
# 4     4   45    55000

# %%
sns.lmplot(x='age',y='premium',data=df)

# %%
reg=linear_model.LinearRegression()

# %%
reg.fit(df[['age']],df['premium'])
# Out:
# LinearRegression()

# %%
reg.predict([[21]])
# Out:
# d:\program\conda\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([13480.])

# %%
reg.predict([[100]])
# Out:
# d:\program\conda\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([154100.])

# %%
reg.coef_
# Out:
# array([1780.])

# %%
reg.intercept_
# Out:
# -23899.999999999985
